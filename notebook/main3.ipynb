# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set("notebook")
from scipy.special import softmax

# %%
a = np.random.random(size=7000)
# a = np.concatenate([_a, _a, softmax(np.random.normal(size=10))])

n_x = 5

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
for a_ in a:
    ax.vlines(a_, 0, 1, color="k", lw=0.1, alpha=0.1)

# %%
x = np.linspace(0, 1, n_x)
y = np.sum(a <= x[:, None], axis=1)
# y = np.zeros_like(x)
# for a_ in a:
#     y += np.heaviside(x - a_, 0)
plt.plot(x, y);

# %%
y2 = np.sum(a <= x[:, None], axis=1)
np.all(y == y2)
# Out:
# True

# %%
a <= x[:, None]
# Out:
# array([[False, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False,  True],
#        [ True, False,  True, ...,  True,  True,  True],
#        [ True, False,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
len(x)
# Out:
# 5

# %%
y2
# Out:
# array([   0, 1719, 3519, 5189, 7000])

# %%
deriv = np.gradient(y, x) / (len(x))

# %%
np.sum(deriv)
# Out:
# 7012.000000000001

# %%
dx = x[1] - x[0]
fig, ax = plt.subplots()
ax.plot(x, deriv / np.sum(y))
ax.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
a = np.arange(3)
np.random.shuffle(a)
a
# Out:
# array([0, 2, 1])

# %%
np.argsort(a)
# Out:
# array([0, 2, 1])
